# %%
import os
import glob
from PIL import Image

root_path = r"D:\LLM\heatmaps"
target_size = (224, 224)

image_files = glob.glob(os.path.join(root_path, "*.png"))
for img_path in image_files:
    img = Image.open(img_path).convert("RGB")
    img_resized = img.resize(target_size, Image.Resampling.LANCZOS)
    img_resized.save(img_path.replace(".png", "_processed.png"))

# %%
# !pip install open_clip_torch
# Out:
# Requirement already satisfied: open_clip_torch in d:\1\anaconda\lib\site-packages (2.23.0)
# Requirement already satisfied: torch>=1.9.0 in d:\1\anaconda\lib\site-packages (from open_clip_torch) (2.5.1)
# Requirement already satisfied: torchvision in d:\1\anaconda\lib\site-packages (from open_clip_torch) (0.20.1)
# Requirement already satisfied: regex in d:\1\anaconda\lib\site-packages (from open_clip_torch) (2024.11.6)
# Requirement already satisfied: ftfy in d:\1\anaconda\lib\site-packages (from open_clip_torch) (6.3.1)
# Requirement already satisfied: tqdm in d:\1\anaconda\lib\site-packages (from open_clip_torch) (4.67.1)
# Requirement already satisfied: huggingface-hub in d:\1\anaconda\lib\site-packages (from open_clip_torch) (0.33.0)
# Requirement already satisfied: sentencepiece in d:\1\anaconda\lib\site-packages (from open_clip_torch) (0.2.0)
# Requirement already satisfied: protobuf in d:\1\anaconda\lib\site-packages (from open_clip_torch) (5.29.0)
# Requirement already satisfied: timm in d:\1\anaconda\lib\site-packages (from open_clip_torch) (1.0.15)
# Requirement already satisfied: filelock in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (4.14.0)
# Requirement already satisfied: networkx in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.3)
# Requirement already satisfied: jinja2 in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (2025.5.1)
# Requirement already satisfied: setuptools in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (75.6.0)
# Requirement already satisfied: sympy==1.13.1 in d:\1\anaconda\lib\site-packages (from torch>=1.9.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\1\anaconda\lib\site-packages (from sympy==1.13.1->torch>=1.9.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in d:\1\anaconda\lib\site-packages (from ftfy->open_clip_torch) (0.2.5)
# Requirement already satisfied: packaging>=20.9 in d:\1\anaconda\lib\site-packages (from huggingface-hub->open_clip_torch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\1\anaconda\lib\site-packages (from huggingface-hub->open_clip_torch) (6.0.2)
# Requirement already satisfied: requests in d:\1\anaconda\lib\site-packages (from huggingface-hub->open_clip_torch) (2.32.4)
# Requirement already satisfied: colorama in d:\1\anaconda\lib\site-packages (from tqdm->open_clip_torch) (0.4.6)
# Requirement already satisfied: safetensors in d:\1\anaconda\lib\site-packages (from timm->open_clip_torch) (0.5.3)
# Requirement already satisfied: numpy in d:\1\anaconda\lib\site-packages (from torchvision->open_clip_torch) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\1\anaconda\lib\site-packages (from torchvision->open_clip_torch) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\1\anaconda\lib\site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\1\anaconda\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\1\anaconda\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\1\anaconda\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\1\anaconda\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2025.6.15)

# %%
import os
import glob
from PIL import Image
import torch
import open_clip
import matplotlib.pyplot as plt

model_name = "hf-hub:microsoft/BiomedCLIP-PubMedBERT_256-vit_base_patch16_224"
model, preprocess = open_clip.create_model_from_pretrained(model_name)
tokenizer = open_clip.get_tokenizer(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

root_path = r"D:\LLM\heatmaps"
image_files = glob.glob(os.path.join(root_path, "*_processed.png"))

labels = [
    "MRI scan showing a glioma tumor with a red heatmap overlay highlighting the affected region",
    "Meningioma tumor visible in brain MRI with red heatmap focusing on the abnormal mass",
    "Pituitary tumor indicated by red heatmap in grayscale MRI brain scan",
    "Red heatmap in brain MRI scan indicates abnormal tumor growth",
    "Brain MRI with strong red heatmap activation around suspected tumor",
    "Segmented tumor region in grayscale brain scan with red highlight",
    "Localized brain tumor with clear red heatmap in medical scan",
    "Medical brain scan showing tumor in red over grayscale MRI",
    "Grayscale MRI showing potential tumor area marked in red",
    "Abnormal tissue detected with red heatmap overlay in brain MRI",
    "MRI showing aggressive tumor highlighted in red heatmap",
    "Red-hot tumor spot visualized in grayscale brain MRI",
    "Brain scan heatmap shows focal lesion in red",
    "Clear red segmentation of tumor in grayscale brain MRI",
    "Red-colored tumor marking in brain scan image",
    "Contrast-enhanced MRI showing a red-marked tumor site",
    "Brain tumor region localized via red thermal-like overlay"
]

text_inputs = tokenizer(labels).to(device)
with torch.no_grad():
    text_features = model.encode_text(text_inputs)
    text_features /= text_features.norm(dim=-1, keepdim=True)

num_images_to_show = 5  # Change if needed
for img_path in image_files[:num_images_to_show]:
    image = Image.open(img_path).convert("RGB")
    image_tensor = preprocess(image).unsqueeze(0).to(device)

    with torch.no_grad():
        image_features = model.encode_image(image_tensor)
        image_features /= image_features.norm(dim=-1, keepdim=True)

        similarities = (image_features @ text_features.T).squeeze(0)
        top_idx = similarities.argmax().item()
        caption = labels[top_idx]

        raw_conf = similarities[top_idx].item()
        confidence = (raw_conf + 1) / 2

    plt.figure(figsize=(8, 6))
    plt.imshow(image)
    plt.title(f"{os.path.basename(img_path)}\nCaption: {caption}\nConfidence: {confidence:.2f}")
    plt.axis("off")
    plt.show()

    print(f"{os.path.basename(img_path)}:")
    print(f"Predicted Caption: {caption}")
    print(f"Confidence: {confidence:.2f}")
    print("-" * 80)
# Out:
# Glioma_enh_1841_processed.png:
# Predicted Caption: Segmented tumor region in grayscale brain scan with red highlight
# Confidence: 0.77
# --------------------------------------------------------------------------------
# Glioma_enh_1842_processed.png:
# Predicted Caption: Segmented tumor region in grayscale brain scan with red highlight
# Confidence: 0.76
# --------------------------------------------------------------------------------
# Glioma_enh_1843_processed.png:
# Predicted Caption: Segmented tumor region in grayscale brain scan with red highlight
# Confidence: 0.76
# --------------------------------------------------------------------------------
# Glioma_enh_1844_processed.png:
# Predicted Caption: MRI scan showing a glioma tumor with a red heatmap overlay highlighting the affected region
# Confidence: 0.76
# --------------------------------------------------------------------------------
# Glioma_enh_1845_processed.png:
# Predicted Caption: Grayscale MRI showing potential tumor area marked in red
# Confidence: 0.75
# --------------------------------------------------------------------------------
